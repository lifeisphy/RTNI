# %%
from IHU_source import *
# symbol, which copy, in/out, 
e1 = [["U", 1, "in", 1], ["X", 1, "in", 1]]
e2 = [["Y", 1, "out", 1], ["U", 1, "out", 1]]
e3 = [["U*", 1, "out", 1], ["Y", 1, "in", 1]]
e4 = [["X", 1, "out", 1], ["U*", 1, "in", 1]]
g = [e1, e2, e3, e4]
gw = [g,1]
print(gw)
visualizeTN(gw)

d = symbols('d')
Eg = integrateHaarUnitary(gw, ["U", [d], [d], d])
print(Eg)
visualizeTN(Eg)
# Out:
# [[[['U', 1, 'in', 1], ['X', 1, 'in', 1]], [['Y', 1, 'out', 1], ['U', 1, 'out', 1]], [['U*', 1, 'out', 1], ['Y', 1, 'in', 1]], [['X', 1, 'out', 1], ['U*', 1, 'in', 1]]], 1]
# 1
# [[[[['X', 1, 'out', 1], ['Y', 1, 'out', 1]], [['X', 1, 'in', 1], ['Y', 1, 'in', 1]]], 1/d]]
# 1/d
